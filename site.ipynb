# %% [markdown]
# <a href="https://colab.research.google.com/github/ramapuramvarshareddy/AI-Archeological-Site-Mapping/blob/main/site.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()   # Choose your dataset.zip file
# Out:
#      <input type="file" id="files-037ce16c-2fc4-4898-9feb-13efab7effab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-037ce16c-2fc4-4898-9feb-13efab7effab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip "vegetation segmentation.v2i.yolov8.zip" -d /content/
# Out:
# Archive:  vegetation segmentation.v2i.yolov8.zip
#  extracting: /content/README.dataset.txt
#  extracting: /content/README.roboflow.txt
#  extracting: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/0-1-14_png.rf.571ebae03cd52ceac7ac1beee7c4e52e.jpg
#  extracting: /content/test/images/0-1-4_png.rf.52706a8121e702d22fe4b744ad603a5e.jpg
#  extracting: /content/test/images/0-13-15_png.rf.a87017e74e06c80c5cb466c08da01027.jpg
#  extracting: /content/test/images/0-13-37_png.rf.24fecf374abb8e9bf3c69fcd642b4814.jpg
#  extracting: /content/test/images/0-2-1_png.rf.1ae60430c36a46864d04f6d5ca407662.jpg
#  extracting: /content/test/images/0-21-20_png.rf.6407b0e4dd15fef6d8a5417032f3ad25.jpg
#  extracting: /content/test/images/0-23-19_png.rf.217c24f9ec7821eb74fe3927e1aba1f2.jpg
#  extracting: /content/test/images/0-28-38_png.rf.e9e04f0f5c6bfc1f4fe2f1f9a5e291ec.jpg
# ...

# %%
# !ls /content/
# Out:
#  data.yaml	       sample_data   valid
#  README.dataset.txt    test	    'vegetation segmentation.v2i.yolov8.zip'
#  README.roboflow.txt   train

# %%
# !cat /content/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['vegetation']
#
# roboflow:
#   workspace: blue-halo
#   project: vegetation-segmentation
#   version: 2
#   license: Public Domain
#   url: https://universe.roboflow.com/blue-halo/vegetation-segmentation/dataset/2

# %%
# !pip install ultralytics --upgrade
# 2️⃣ (Optional) Install other dependencies
# !pip install numpy pandas scikit-learn matplotlib seaborn opencv-python rasterio geopandas folium albumentations
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 109.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# 4️⃣ Load your YOLOv8 segmentation model
model = YOLO("yolov8n-seg.pt")

# 5️⃣ Train your model
model.train(
    data="/content/data.yaml",
    epochs=30,
    imgsz=640,
    device=0
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
